# %%
# Exercise from repository https://github.com/microsoft/ML-For-Beginners
# Chapter 2. Regression
# 1. Tools

# %%
# ESTATEMENT
"""In this section, you will work with a small dataset about diabetes that is built into Scikit-learn for learning purposes. 
Imagine that you wanted to test a treatment for diabetic patients. 
Machine Learning models might help you determine which patients would respond better to the treatment, 
based on combinations of variables. Even a very basic regression model, when visualized, 
might show information about variables that would help you organize your theoretical clinical trials."""
# Out:
# 'In this section, you will work with a small dataset about diabetes that is built into Scikit-learn for learning purposes. \nImagine that you wanted to test a treatment for diabetic patients. \nMachine Learning models might help you determine which patients would respond better to the treatment, \nbased on combinations of variables. Even a very basic regression model, when visualized, \nmight show information about variables that would help you organize your theoretical clinical trials.'

# %%
# Import libraries and modules
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
# Load dataset from scikit-learn
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187235 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990842 -0.01764613]

# %%
# 442 items in arrays of 10 elements 
# 422 samples from patients and 10 features from each of them

# %%
# select a portion of this dataset to plot by arranging it into a new array using numpy's newaxis function
X = X[:, np.newaxis, 2] # Takes the third element of the array as independent variable
print(X.shape)
# Out:
# (442, 1)

# %%
# split both the data (X) and the target (y) into test and training sets with scikit-learn
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %%
# Load up the linear regression model and train it with your X and y training sets using model.fit()
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# create a prediction using test data, using the function predict(). This will be used to draw the line between data groups
y_pred = model.predict(X_test)

# %%
#  Create a scatterplot of all the X and y test data, and use the prediction to draw a line in the most appropriate place, 
# between the model's data groupings.
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Scaled BMIs')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
plt.show()

# %%
# CHALLENGE
# Plot a different variable from this dataset. Hint: edit this line: X = X[:, np.newaxis, 2]
X, y = datasets.load_diabetes(return_X_y=True)
X2 = X[:, np.newaxis, 3]
# split both the data (X) and the target (y) into test and training sets with scikit-learn
X2_train, X2_test, y_train, y_test = model_selection.train_test_split(X2, y, test_size=0.33)
# Load up the linear regression model and train it with your X and y training sets using model.fit()
model = linear_model.LinearRegression()
model.fit(X2_train, y_train)
# create a prediction using test data, using the function predict(). This will be used to draw the line between data groups
y_pred = model.predict(X2_test)
#  Create a scatterplot of all the X and y test data, and use the prediction to draw a line in the most appropriate place, 
# between the model's data groupings.
plt.scatter(X2_test, y_test,  color='black')
plt.plot(X2_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Average Blood pressure')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against Bp')
plt.show()
